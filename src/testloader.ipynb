# %% [markdown]
# # This notebook is used to test the data loading modules (storage.py, extraction.py)

# %%
from config import settings
import h5py
import logging
import logging.config
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import string
import yaml

import storage
import extraction

# %matplotlib inline

# %%
log_file_path = settings.log_config
def setupLogging():
    with open(log_file_path, 'rt') as file:
        config = yaml.safe_load(file.read())
        logging.config.dictConfig(config)

# %%
setupLogging()

# %%
# Read TSV files
train_rawdata_file_path = settings.train_raw_data
validation_rawdata_file_path = settings.validation_raw_data

#train_df = pd.read_table(train_rawdata_file_path, header = None, names = ['caption', 'url'] )
validate_df = pd.read_table(validation_rawdata_file_path, header = None, names = ['caption', 'url']) 

#train_df.head(20)
validate_df.head(5)

# %%
train_df[train_df['caption'].str.contains("panda")]

# %%
# Extracts image and caption from tsv and store padded(image),caption and HTTPStatus code
# into a train or validation hdf5 file

# Set image size
img_size = 300 , 300 
start_index = 0

# Extraction and Storage
#extraction.request_data_and_store(validate_df, size, "validate", start_index) 
#extraction.request_data_and_store(train_df, size, "train", start_index - 100)
extraction.request_data_and_store(validate_df, img_size, "train_le_retour", start_index)

# %%
def extract_data(set_name, img_size, start_index=0):
# Extracts image and caption from tsv and store padded(image),caption and HTTPStatus code
# into a train or validation hdf5 file
    logger = logging.getLogger()
    data_df = None
    if set_name == "train":
        # Read TSV file
        train_rawdata_file_path = settings.train_raw_data
        data_df = pd.read_table(train_rawdata_file_path, header = None, names = ['caption', 'url'] )
        
    elif set_name == "validate":
        # Read TSV file
        validation_rawdata_file_path = settings.validation_raw_data
        data_df = pd.read_table(validation_rawdata_file_path, header = None, names = ['caption', 'url']) 

    else:
        logger.info("loader.extract_data: get yout set_name right! What is it you want to load again?")
        return
    
    # Extract images and stores images/captions
    data_df = data_df.head(40)
    extraction.request_data_and_store(data_df, img_size, set_name, start_index)
    logger.info("loader.extract_data: all the data have been extracted and stored.")

# %%
# Get last stored index
last_index = storage.get_last_stored_index("train")
print(last_index)

#size = 224, 224
#extract_data("train", size, last_index)

# %%
from config import settings
print(settings.data_path)
print(settings.start_seq)
print(settings.end_seq)
print(settings.image_shape[2])

# %%
request_data_and_store("xxtrain", 10, 20 )

# %%
 extraction.extract_resnet_features_and_store("train", 10184, 100000)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image_input (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           image_input[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           conv5_block3_out[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None
# 2020-09-23 03:50:34,726 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809109584 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,741 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809109584 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,829 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809109584 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,835 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809109584 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,840 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809028048 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,850 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809028048 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,864 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809028048 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,868 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809028048 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,870 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809027600 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,875 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027600 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,893 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809027600 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,895 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027600 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,896 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809027344 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,903 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027344 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,912 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809027344 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,914 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027344 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,917 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809028048 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,922 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809028048 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,935 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809028048 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,937 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809028048 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,939 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809027408 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,943 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027408 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,955 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809027408 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,957 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027408 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,960 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809027344 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,964 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027344 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,973 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809027344 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,975 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027344 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,976 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809028048 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,981 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809028048 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,989 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809028048 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,992 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809028048 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:34,995 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809027408 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,000 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027408 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,008 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809027408 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,011 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027408 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,013 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809027344 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,018 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027344 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,026 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809027344 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,029 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027344 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,030 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809028048 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,035 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809028048 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,049 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809028048 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,051 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809028048 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,052 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809027856 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,055 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027856 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,071 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809027856 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,073 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027856 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,074 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809027408 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,081 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027408 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,088 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809027408 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,091 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027408 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,092 - INFO <PID 2002:MainProcess> - MainThread - root - INFO - extraction:request_data_and_store-- Before queue ACQUIRE -- 10196
# 2020-09-23 03:50:35,093 - INFO <PID 2002:MainProcess> - MainThread - root - INFO - extraction:request_data_and_store-- Before executor SUBMIT -- 10196
# 2020-09-23 03:50:35,095 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - root - INFO - extraction:get_image_resnet_features: train index:10196 extracting
# 2020-09-23 03:50:35,096 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809027984 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,098 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - filelock - DEBUG - Attempting to acquire lock 140127809108240 on ../data/img/train_0.h5.lock
# 2020-09-23 03:50:35,105 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027984 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,113 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - filelock - INFO - Lock 140127809108240 acquired on ../data/img/train_0.h5.lock
# 2020-09-23 03:50:35,114 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809027984 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,219 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - root - DEBUG - read_image function found: train-- Index# 10196 Status: 200
# 2020-09-23 03:50:35,220 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027984 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,221 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - root - DEBUG - storage.read_image: Get image
# 2020-09-23 03:50:35,223 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809027600 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,236 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - filelock - DEBUG - Attempting to release lock 140127809108240 on ../data/img/train_0.h5.lock
# 2020-09-23 03:50:35,238 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809027600 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 03:50:35,240 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - filelock - INFO - Lock 140127809108240 released on ../data/img/train_0.h5.lock
# 2020-09-23 03:50:35,252 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809027600 on ../data/img/resnet_train_0.h5.lock
# ...
# 2020-09-23 04:00:51,416 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - filelock - INFO - Lock 140127809221712 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:51,419 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - root - INFO - extraction:get_image_resnet_features: train index:10957 extracting
# 2020-09-23 04:00:51,425 - INFO <PID 2002:MainProcess> - MainThread - root - INFO - extraction:request_data_and_store-- Before executor SUBMIT -- 11052
# 2020-09-23 04:00:51,434 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140125034386896 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:51,428 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - filelock - DEBUG - Attempting to acquire lock 140125031577552 on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:51,492 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140125034386896 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:51,576 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140125034386896 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:51,608 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - filelock - INFO - Lock 140125031577552 acquired on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:51,751 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140125034386896 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:52,014 - INFO <PID 2002:MainProcess> - MainThread - root - INFO - extraction:request_data_and_store-- Before queue ACQUIRE -- 11053
# 2020-09-23 04:00:51,951 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - root - DEBUG - read_image function: train-- Index# 10957 Status: 404
# 2020-09-23 04:00:52,052 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - filelock - DEBUG - Attempting to release lock 140125031577552 on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:52,056 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - filelock - INFO - Lock 140125031577552 released on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:52,057 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - root - INFO - resnet_train-- Store Handler Index#10957 Http code: 404
# 2020-09-23 04:00:52,106 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - root - INFO - resnet_trainstore_status.exist:-- URL#10957 Storing status--- 404
# 2020-09-23 04:00:52,111 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - filelock - DEBUG - Attempting to acquire lock 140124992807568 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:52,197 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - filelock - INFO - Lock 140124992807568 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:52,453 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - filelock - DEBUG - Attempting to release lock 140124992807568 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:52,459 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - filelock - INFO - Lock 140124992807568 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:52,479 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - root - INFO - extraction:get_image_resnet_features: train index:10958 extracting
# 2020-09-23 04:00:52,551 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - filelock - DEBUG - Attempting to acquire lock 140124992807056 on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:52,534 - INFO <PID 2002:MainProcess> - MainThread - root - INFO - extraction:request_data_and_store-- Before executor SUBMIT -- 11053
# 2020-09-23 04:00:52,566 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - filelock - INFO - Lock 140124992807056 acquired on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:52,692 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140127809221712 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:53,008 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - root - DEBUG - read_image function found: train-- Index# 10958 Status: 200
# 2020-09-23 04:00:53,010 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - root - DEBUG - storage.read_image: Get image
# 2020-09-23 04:00:53,011 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809221712 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:53,189 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - filelock - DEBUG - Attempting to release lock 140124992807056 on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:53,209 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140127809221712 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:53,301 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_1 - filelock - INFO - Lock 140124992807056 released on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:53,307 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140127809221712 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:53,463 - INFO <PID 2002:MainProcess> - MainThread - root - INFO - extraction:request_data_and_store-- Before queue ACQUIRE -- 11054
# 2020-09-23 04:00:54,396 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - root - INFO - extraction:get_image_resnet_features: train index:10954 features extracted
# 2020-09-23 04:00:54,431 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - root - INFO - resnet_train-- Store Handler Index#10954 Http code: 200
# 2020-09-23 04:00:54,441 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - root - INFO - storage.store_imageresnet_train-- INDEX#10954 STORING---
# 2020-09-23 04:00:54,444 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - filelock - DEBUG - Attempting to acquire lock 140125002060688 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:54,552 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - filelock - INFO - Lock 140125002060688 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:54,572 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - root - DEBUG - storage.store_imageresnet_train-- INDEX#10954 GROUP---
# 2020-09-23 04:00:54,677 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - root - INFO - storage.store_imageresnet_train-- URL#10954 IMAGE STORED---
# 2020-09-23 04:00:54,689 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - filelock - DEBUG - Attempting to release lock 140125002060688 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:54,694 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - filelock - INFO - Lock 140125002060688 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:54,712 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - root - INFO - extraction:get_image_resnet_features: train index:10959 extracting
# 2020-09-23 04:00:54,716 - INFO <PID 2002:MainProcess> - MainThread - root - INFO - extraction:request_data_and_store-- Before executor SUBMIT -- 11054
# 2020-09-23 04:00:54,718 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - filelock - DEBUG - Attempting to acquire lock 140125002060688 on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:54,719 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140125003545680 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:54,801 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140125003545680 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:54,801 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - filelock - INFO - Lock 140125002060688 acquired on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:54,811 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140125003545680 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:54,983 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140125003545680 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:54,968 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - root - DEBUG - read_image function found: train-- Index# 10959 Status: 200
# 2020-09-23 04:00:54,991 - INFO <PID 2002:MainProcess> - MainThread - root - INFO - extraction:request_data_and_store-- Before queue ACQUIRE -- 11055
# 2020-09-23 04:00:54,993 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - root - DEBUG - storage.read_image: Get image
# 2020-09-23 04:00:55,091 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - filelock - DEBUG - Attempting to release lock 140125002060688 on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:55,167 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_0 - filelock - INFO - Lock 140125002060688 released on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:56,819 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - root - INFO - extraction:get_image_resnet_features: train index:10953 features extracted
# 2020-09-23 04:00:56,824 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - root - INFO - resnet_train-- Store Handler Index#10953 Http code: 200
# 2020-09-23 04:00:56,829 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - root - INFO - storage.store_imageresnet_train-- INDEX#10953 STORING---
# 2020-09-23 04:00:56,831 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - filelock - DEBUG - Attempting to acquire lock 140127122090320 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:56,915 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - filelock - INFO - Lock 140127122090320 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:56,957 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - root - DEBUG - storage.store_imageresnet_train-- INDEX#10953 GROUP---
# 2020-09-23 04:00:57,006 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - root - INFO - storage.store_imageresnet_train-- URL#10953 IMAGE STORED---
# 2020-09-23 04:00:57,033 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - filelock - DEBUG - Attempting to release lock 140127122090320 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:57,037 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - filelock - INFO - Lock 140127122090320 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:57,056 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - root - INFO - extraction:get_image_resnet_features: train index:10960 extracting
# 2020-09-23 04:00:57,056 - INFO <PID 2002:MainProcess> - MainThread - root - INFO - extraction:request_data_and_store-- Before executor SUBMIT -- 11055
# 2020-09-23 04:00:57,082 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - filelock - DEBUG - Attempting to acquire lock 140125003130704 on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:57,084 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140125003130192 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:57,124 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - filelock - INFO - Lock 140125003130704 acquired on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:57,179 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140125003130192 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:57,363 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140125003130192 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:57,371 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140125003130192 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:57,373 - INFO <PID 2002:MainProcess> - MainThread - root - INFO - extraction:request_data_and_store-- Before queue ACQUIRE -- 11056
# 2020-09-23 04:00:57,366 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - root - DEBUG - read_image function found: train-- Index# 10960 Status: 200
# 2020-09-23 04:00:57,396 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - root - DEBUG - storage.read_image: Get image
# 2020-09-23 04:00:57,457 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - filelock - DEBUG - Attempting to release lock 140125003130704 on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:57,460 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_3 - filelock - INFO - Lock 140125003130704 released on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:57,956 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - root - INFO - extraction:get_image_resnet_features: train index:10956 features extracted
# 2020-09-23 04:00:57,958 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - root - INFO - resnet_train-- Store Handler Index#10956 Http code: 200
# 2020-09-23 04:00:57,959 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - root - INFO - storage.store_imageresnet_train-- INDEX#10956 STORING---
# 2020-09-23 04:00:57,961 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - filelock - DEBUG - Attempting to acquire lock 140125000382224 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:58,068 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - filelock - INFO - Lock 140125000382224 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:58,138 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - root - DEBUG - storage.store_imageresnet_train-- INDEX#10956 GROUP---
# 2020-09-23 04:00:58,164 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - root - INFO - storage.store_imageresnet_train-- URL#10956 IMAGE STORED---
# 2020-09-23 04:00:58,223 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - filelock - DEBUG - Attempting to release lock 140125000382224 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:58,228 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - filelock - INFO - Lock 140125000382224 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:58,229 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - root - INFO - extraction:get_image_resnet_features: train index:10961 extracting
# 2020-09-23 04:00:58,230 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - filelock - DEBUG - Attempting to acquire lock 140127122090320 on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:58,234 - INFO <PID 2002:MainProcess> - MainThread - root - INFO - extraction:request_data_and_store-- Before executor SUBMIT -- 11056
# 2020-09-23 04:00:58,235 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to acquire lock 140125003132304 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:58,250 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - filelock - INFO - Lock 140127122090320 acquired on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:58,281 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140125003132304 acquired on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:58,403 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - root - DEBUG - read_image function found: train-- Index# 10961 Status: 200
# 2020-09-23 04:00:58,457 - DEBUG <PID 2002:MainProcess> - MainThread - filelock - DEBUG - Attempting to release lock 140125003132304 on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:58,463 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - root - DEBUG - storage.read_image: Get image
# 2020-09-23 04:00:58,519 - INFO <PID 2002:MainProcess> - MainThread - filelock - INFO - Lock 140125003132304 released on ../data/img/resnet_train_0.h5.lock
# 2020-09-23 04:00:58,538 - DEBUG <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - filelock - DEBUG - Attempting to release lock 140127122090320 on ../data/img/train_0.h5.lock
# 2020-09-23 04:00:58,538 - INFO <PID 2002:MainProcess> - MainThread - root - INFO - extraction:request_data_and_store-- Before queue ACQUIRE -- 11057
# 2020-09-23 04:00:58,599 - INFO <PID 2002:MainProcess> - ThreadPoolExecutor-3_4 - filelock - INFO - Lock 140127122090320 released on ../data/img/train_0.h5.lock

# %%
def clean_caption(caption):
    # prepare translation table for removing punctuation
    table = str.maketrans('', '', string.punctuation)

    # tokenize
    desc = caption.split()
    # convert to lower case
    desc = [word.lower() for word in desc]
    # remove punctuation from each token
    desc = [w.translate(table) for w in desc]
    # remove hanging 's' and 'a'
    desc = [word for word in desc if len(word)>1]
    # remove tokens with numbers in them
    desc = [word for word in desc if word.isalpha()]
    # store as string
    caption = settings.start_seq +" "+ ' '.join(desc) +" "+ settings.end_seq
    return caption

# %%
clean_caption("Les 3 petits cochons $ et *?")

# %%
def clean_caption(caption):
    # prepare translation table for removing punctuation
    table = str.maketrans('', '', string.punctuation)

    # tokenize
    desc = caption.split()
    # convert to lower case
    desc = [word.lower() for word in desc]
    # remove punctuation from each token
    desc = [w.translate(table) for w in desc]
    # remove hanging 's' and 'a'
    desc = [word for word in desc if len(word)>1]
    # remove tokens with numbers in them
    desc = [word for word in desc if word.isalpha()]
    # store as string
    #caption = settings.start_seq +" "+ ' '.join(desc) +" "+ settings.end_seq
    return ' '.join(desc)

# %%
def final_caption(caption):
    desc = settings.start_seq +" "+ clean_caption(caption) +" "+ settings.end_seq
    return desc

# %%
final_caption("Les 3 petits cochons $ et *?")
